# %% [markdown]
# # AEG Visualization
#
# Estimate adversarial entropy gradients from effort/entropy observations.

# %%
from simulation.aeg_model import AdversarialEntropyGradient, EntropyObservation
model = AdversarialEntropyGradient([EntropyObservation(0, 10), EntropyObservation(1, 7), EntropyObservation(3, 4)])
model.marginal_efficiency()
