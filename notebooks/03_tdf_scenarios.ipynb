# %% [markdown]
# # TDF Scenarios
#
# Explore credential trust decay under breach events.

# %%
from simulation.tdf_model import CredentialTrust, BreachEvent
trust = CredentialTrust(decay_rate=0.04)
trust.add_breach(BreachEvent(time=12, severity=0.35, label='public breach'))
trust.timeline(0, 24, 5)
