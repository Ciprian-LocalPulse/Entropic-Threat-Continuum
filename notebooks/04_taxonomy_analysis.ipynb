# %% [markdown]
# # Taxonomy Analysis
#
# Validate and inspect the machine-readable Plesca Taxonomy.

# %%
from taxonomy.taxonomy_validator import load_taxonomy, validate_taxonomy
data = load_taxonomy('../src/taxonomy/plesca_taxonomy.json')
validate_taxonomy(data)
