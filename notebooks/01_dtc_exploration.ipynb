# %% [markdown]
# # DTC Exploration
#
# Compact notebook for running the Dark Topology Conjecture simulation.

# %%
from simulation.dtc_simulation import SimulationConfig, run_simulation
aggregate = run_simulation(SimulationConfig(n_nodes=40, n_runs=3, n_configs=4, seed=42))
aggregate
